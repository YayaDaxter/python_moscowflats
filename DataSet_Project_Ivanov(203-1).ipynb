# %% [markdown]
# # Info:

# %% [markdown]
# **[*My Dataset*](https://www.kaggle.com/hugoncosta/price-of-flats-in-moscow)**

# %% [markdown]
# **The following dataset was provided as a course material for Econometrics, taught by Boris Demeshev, professor at the Higher School of Economics Moscow. The origin is non specified. The following dataset gives a small sample of the prices of flats in Moscow.**

# %% [markdown]
# Submission format: Jupyter Notebook, send a link to the file to the Google form. Link to the form will be added later.
#
# Project description:
# Find a dataset with text data and analyze it the following way.
# 1. Output descriptive statistics of the dataset: mean, median, standard deviation. Do this for at least 3 numerical fields.
# 2. Plot at least 3 numerical fields. Choose the plot type based on the data. It may make more sense to do a scatterplot, a regular plot, a histogram or something else.
# 3. Do at least 2 comparisons similar to the ones in the Titanic example. "What are the distributions of the column A for different values of the column B?" Output as either numbers or plots.
# 4. Describe your results in 2-3 paragraphs of text. What you can see from the plot, from the statistics and comparisons.

# %%
# disable warnings Anaconda
import warnings
warnings.simplefilter('ignore')
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('darkgrid')

# %% [markdown]
# # Legend:

# %% [markdown]
#   ####  ***price:***
#   ##### **<font color='green'>Apartment price in thousands of $dollars$.</font>**
#   ####  ***totsp:***
#   ##### **<font color='red'>Total area of the apartment, sq. m. .</font>**
#   ####  ***livesp:***
#   ##### **<font color='blue'>Living area of the apartment, sq. m .</font>**
#   ####  ***kitsp:***
#   ##### **<font color='crimson'>Kitchen area, sq. m.</font>**
#   ####  ***dist:***
#   ##### **<font color='olive'>Distance from the city center in km. .</font>**
#   ####  ***metrdist:***
#   ##### **<font color='mediumvioletred'>Distance to the metro station in minutes.</font>**
#   ####  ***walk:***
#   ##### **<font color='indianred'>1-walk from the metro, 0-by public transport.</font>**
#   ####  ***brick:***
#   ##### **<font color='darkcyan'>1-brick, monolith; 0-other.</font>**
#   ####  ***floor:***
#   ##### **<font color='royalblue'>1-floor except the first and last; 0-otherwise.</font>**

# %%
df = pd.read_csv("flats_moscow.csv")
df.pop('code')
df.pop('Unnamed: 0')
print('-'*100)
# Out:
# ----------------------------------------------------------------------------------------------------

# %%
df
# Out:
#       price  totsp  livesp  kitsp  dist  metrdist  walk  brick  floor
# 0        81     58      40    6.0  12.5         7     1      1      1
# 1        75     44      28    6.0  13.5         7     1      0      1
# 2       128     70      42    6.0  14.5         3     1      1      1
# 3        95     61      37    6.0  13.5         7     1      0      1
# 4       330    104      60   11.0  10.5         7     0      1      1
# ...     ...    ...     ...    ...   ...       ...   ...    ...    ...
# 2035    110     77      45   10.0  12.0         5     0      0      1
# 2036     95     60      43    6.0   9.0         5     0      0      1
# 2037     95     60      46    5.0  10.5         5     1      0      1
# 2038    129     76      48   10.0  12.5         5     0      0      1
# 2039    103     64      45    7.0  15.5         5     1      0      1
#
# [2040 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2040 entries, 0 to 2039
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   price     2040 non-null   int64
#  1   totsp     2040 non-null   int64
#  2   livesp    2040 non-null   int64
#  3   kitsp     2040 non-null   float64
#  4   dist      2040 non-null   float64
#  5   metrdist  2040 non-null   int64
#  6   walk      2040 non-null   int64
#  7   brick     2040 non-null   int64
#  8   floor     2040 non-null   int64
# dtypes: float64(2), int64(7)
# memory usage: 143.6 KB

# %%
df.describe(include='all')
# Out:
#              price        totsp       livesp        kitsp         dist  \
# count  2040.000000  2040.000000  2040.000000  2040.000000  2040.000000
# mean    127.496569    73.084314    46.337255     8.898529    11.015686
# std      51.878220    15.123450     7.894348     2.787073     3.375539
# min      50.000000    44.000000    28.000000     5.000000     3.000000
# 25%      95.000000    62.000000    42.000000     7.000000     9.000000
# 50%     115.000000    73.500000    45.000000     9.000000    12.000000
# 75%     142.000000    79.000000    50.000000    10.000000    13.500000
# max     730.000000   192.000000   102.000000    25.000000    17.000000
#
#           metrdist         walk        brick        floor
# count  2040.000000  2040.000000  2040.000000  2040.000000
# mean      8.117157     0.685784     0.323039     0.790686
# std       3.815574     0.464317     0.467752     0.406918
# min       1.000000     0.000000     0.000000     0.000000
# ...

# %% [markdown]
# Main description of dataset. There are no null values.
# ***(2040 values in every column)***

# %%
a = sns.relplot(x="totsp", y="price", hue='metrdist', data=df)
a.fig.set_figwidth(9)
a.fig.set_figheight(9)

# %% [markdown]
# The apartments cost depending on their total area square and metrdist
# **(The main distribution)**

# %%
a = sns.relplot(x="totsp", y="price", kind="line", data=df)
a.fig.set_figwidth(9)
a.fig.set_figheight(9)

# %% [markdown]
# It is easy to observe the main tendency in cost depending on the change of total square.

# %%
a = sns.relplot(x="totsp", y="kitsp", hue="price", kind="scatter", data=df)
a.fig.set_figwidth(9)
a.fig.set_figheight(9)

# %% [markdown]
# It is noticeable that the price is affected mostly by total square of a flat than kitchen square of the flat.

# %%
a = sns.catplot(x="brick", y="price", kind="boxen",data=df)
a.fig.set_figwidth(9)
a.fig.set_figheight(9)

# %% [markdown]
# Prices for Aparments which were made of premium materials are much higher as the same from other materials.

# %% [markdown]
# ## Some statistics

# %%
df.pivot_table(['price'],['walk'], aggfunc='median')
# Out:
#       price
# walk
# 0       109
# 1       120

# %% [markdown]
# Median flat price, depending on the possibility of walking without using any transport.

# %%
print('Average distance from the apartment to the center:')
av_dist = df['dist'].median()
av_dist
# Out:
# Average distance from the apartment to the center:
# 12.0

# %%
print('Comparison of average prices for apartments in different regions:')
print(round(df[df['dist'] < av_dist]['price'].mean(),2),';',round(df[df['dist'] > av_dist]['price'].mean(),2))
# Out:
# Comparison of average prices for apartments in different regions:
# 146.63 ; 112.97

# %%
print('Average apartment totsp:')
av_sp = df['totsp'].mean()
av_sp = round(av_sp)
av_sp
# Out:
# Average apartment totsp:
# 73

# %%
print('Average apartment livesp and kitsp:')
l_sp = df['livesp'].mean()
l_sp = round(l_sp)
k_sp = df['kitsp'].mean()
k_sp = round(k_sp)
print(l_sp,';',k_sp)
# Out:
# Average apartment livesp and kitsp:
# 46 ; 9

# %%
df['price'].std()
# Out:
# 51.87821960549713

# %%
print('Comparison of average prices for apartments on different floors:')
print(round(df[df['floor'] == 0]['price'].mean(),2),';',round(df[df['floor'] == 1]['price'].mean(),2))
# Out:
# Comparison of average prices for apartments on different floors:
# 114.13 ; 131.03

# %%
print('Comparison of average prices for apartments in different buildings:')
print(round(df[df['brick'] == 0]['price'].mean(),2),';',round(df[df['brick'] == 1]['price'].mean(),2))
# Out:
# Comparison of average prices for apartments in different buildings:
# 118.15 ; 147.08
